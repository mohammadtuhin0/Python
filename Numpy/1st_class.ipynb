# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

print(list1 + list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import numpy as np
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

print(arr1 + arr2)
# Out:
# [5 7 9]

# %%
menu = np.array(['chese', 'bbq', 'veg', 'spicy'])
print(menu)
# Out:
# ['chese' 'bbq' 'veg' 'spicy']

# %%
prices = [100, 200, 150, 220]
print(prices)
# Out:
# [100, 200, 150, 220]

# %%
prices_np = np.array([100, 200, 150, 220])
prices = prices_np * 0.8
print(prices)
# Out:
# [ 80. 160. 120. 176.]

# %%
empty_table = np.zeros((2, 3))
print(empty_table)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
full_table = np.ones((3, 3))
print(full_table)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
bbq_boxes = np.full((2, 3), 'bbq')
print(bbq_boxes)
# Out:
# [['bbq' 'bbq' 'bbq']
#  ['bbq' 'bbq' 'bbq']]

# %%
kids_order = np.random.randint(1, 8, (2, 3))
print(kids_order)
# Out:
# [[6 6 7]
#  [7 4 5]]

# %%
surprise_toppings = np.random.rand(2, 3)
print(surprise_toppings)
# Out:
# [[0.36985189 0.25838879 0.65000949]
#  [0.94807416 0.75854265 0.52111285]]

# %%
signature_pizzas = np.identity(3)
print(signature_pizzas)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
delivery_items = np.arange(0, 70, 15)
print(delivery_items)
# Out:
# [ 0 15 30 45 60]

# %%
cooking_shifts = np.linspace(0, 70, 5)
print(cooking_shifts)
# Out:
# [ 0.  17.5 35.  52.5 70. ]

# %%
orders = np.array(['cheese', 'veg', 'spicy', 'bbq'])
print(orders[2])
# Out:
# spicy

# %%
print(orders[:2])
# Out:
# ['cheese' 'veg']

# %%
sales = np.array([2000, 1500, 8000, 3500])
print("Max sales index : ", np.argmax(sales))
print("Max sales : ", np.max(sales))
# Out:
# Max sales index :  2
# Max sales :  8000

# %%
print("Min sales ")
